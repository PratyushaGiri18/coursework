# %%
#1)
def gcd(a, b):
    while b!= 0:
        a, b = b, a % b
    return a
print(gcd(48, 18))
# Out:
# 6

# %%
'''if we use the above code:

If one number is negative, Python’s % still works, but the final result may be negative
#To ensure GCD  always non-negative we can modify like this'''
# Out:
# 'if we use the above code:\n\nIf one number is negative, Python’s % still works, but the final result may be negative\n#To ensure GCD  always non-negative we can modify like this'

# %%
def gcd(a, b):
    if a== 0 and b== 0:
        raise ValueError('gcd undefined for (0, 0)')
    while b:
        a, b = b, a % b
    return a if a> 0 else -a
gcd(-48, 18)
# Out:
# 6

# %%
#2)
#part 1:
def euler_limit(n):
    return (1 + 1/n) ** n

# %%
#part2:
euler_limit(10**16)
# Out:
# 1.0

# %%
'''it is returning 1.0.Because of floating point precision.
When n is extremely large:1/n becomes so small that the computer cannot represent it accurately.
 so, 1 + 1/n  →  becomes 1.0 and (1.0) ** n = 1.0 so So it incorrectly returns 1.0 instead of e.'''
# Out:
# 'it is returning 1.0.Because of floating point precision.\nWhen n is extremely large:1/n becomes so small that the computer cannot represent it accurately.\n so, 1 + 1/n  →  becomes 1.0 and (1.0) ** n = 1.0 so So it incorrectly returns 1.0 instead of e.'

# %%
# part 3
def euler_sum(n):
    total = 0.0
    factorial = 1  
    for k in range(n):
        if k > 0:
            factorial *= k  
        total += 1 / factorial
    return total
euler_sum(4)
# Out:
# 2.6666666666666665

# %%
#part 4
def euler_approx(epsilon):
    total = 0
    factorial = 1
    k = 0
    while True:
        term = 1 / factorial
        if term < epsilon:
            break
        total += term
        k += 1
        factorial *= k
    return total

# %%
#part 5
def true_e():
    total = 0
    factorial = 1
    for k in range(20):   
        if k > 0:
            factorial *= k
        total += 1 / factorial
    return total
# error for euler sum:
def print_euler_sum_error(n):
    e = true_e()
    for k in range(1, n+1):
        approx = euler_sum(k)
        error = approx - e
        print(error)

# %%
# error for euler limit:
def print_euler_lim_error(n):
    e = true_e()
    for k in range(1, n+1):
        approx = euler_limit(k)
        error = approx - e
        print(error)

# %%
print_euler_sum_error(5)
# Out:
# -1.7182818284590455
# -0.7182818284590455
# -0.21828182845904553
# -0.051615161792379016
# -0.009948495125712498

# %%
#part6
''' the sum method is better because The limit method suffers from floating point precision for large n.and the sum
method is more numerically stable'''
# Out:
# ' the sum method is better because The limit method suffers from floating point precision for large n.and the sum\nmethod is more numerically stable'

# %%
#3)
#part 1:
def is_power_of_2(n):
    if n == 1:
        return True
    if n % 2 != 0:
        return False
    return is_power_of_2(n // 2)

# %%
#part2
def is_power(b, n):
    if n == 1:
        return True
    if n % b != 0:
        return False
    return is_power(b, n // b)

# %%
# I have used ai tools while doing this assignment.
# the link of github repository is 
https://github.com/PratyushaGiri18/coursework/tree/main
